# %% [markdown]
# damping 10% noise 5%

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
print("TensorFlow version:", tf.__version__)
import pandas as pd
import numpy as np
# Out:
# TensorFlow version: 2.8.0

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df = pd.read_csv (r'/content/drive/MyDrive/CNN dataset/15400x600_dataset.csv',header=None)
# df=df.iloc[:,[0,8,16,24,32,40,48,56,64,72,80,88]]
df=df.to_numpy()
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# scaler=MinMaxScaler((-1,1))
scaler = StandardScaler()
scaler.fit(df[:,:])
# scaler.fit(df[:,:])
scaler.fit_transform(df)
df= scaler.transform(df)
print(df)
print (df)
print(df.shape)
# df=df.to_numpy()
y= pd.read_csv(r'/content/drive/MyDrive/CNN dataset/y_8th dof_15400x1.csv',header=None)
# y=y.iloc[:,[0,8,16,24,32,40,48,56,64,72,80,88]]
# print(y.to_numpy())
# print(y.shape)
#y=y.to_numpy()
y=y.to_numpy()

# y[y == 1.0] = 6
# y[y == 0.5] = 1
# y[y == 0.7] = 2
# y[y == 0.2] = 3
# y[y == 0.9] = 4
# y[y == 0.6] = 5
# y[y == 0.8] = 7
# y[y == 0.4] = 8
# print(y)

# yy=np.array(96,8)

# for i in range(len(y)):
#     if (y.iloc[i].to_numpy() == 0.5):
#             yy.append([1 0 0 0 0 0 0 0])
#     elif y.iloc[i].to_numpy() == 0.7:
#             yy.append([0 1 0 0 0 0 0 0])
#     elif y.iloc[i].to_numpy() == 0.2:
#             yy.append(0 0 1 0 0 0 0 0)
#     elif y.iloc[i].to_numpy() == 0.9:
#             yy.append(0 0 0 1 0 0 0 0)
#     elif y.iloc[i].to_numpy() == 0.6:
#             yy.append(0 0 0 0 1 0 0 0)
#     elif y.iloc[i].to_numpy() == 1:
#             yy.append(0 0 0 0 0 1 0 0)
#     elif y.iloc[i].to_numpy() == 0.8:
#             yy.append(0 0 0 0 0 0 1 0)
#     elif y.iloc[i].to_numpy() == 0.4:
#             yy.append(0 0 0 0 0 0 1)
# scaler = MinMaxScaler((-1,1))
scaler.fit(y[:,:])
scaler.fit_transform(y)
y= scaler.transform(y)
print(y.shape)
# plot(y)
# Out:
# [[ 0.05528027  0.0553279   0.05538907 ... -0.86875156 -0.62140372
#   -0.37260496]
#  [ 0.05533849  0.05539913  0.0554553  ... -0.62133218 -0.37256003
#   -0.16768072]
#  [ 0.05540972  0.05546537  0.05549373 ... -0.37249459 -0.16763836
#   -0.04338958]
#  ...
#  [ 0.23574443  0.23104407  0.22471624 ... -0.001897   -0.00183568
#   -0.00175852]
#  [ 0.2310549   0.22472652  0.21705258 ... -0.00177932 -0.00171824
#   -0.00164132]
#  [ 0.22473735  0.21706286  0.20918304 ... -0.00166188 -0.00160105
#   -0.00152438]]
# [[ 0.05528027  0.0553279   0.05538907 ... -0.86875156 -0.62140372
#   -0.37260496]
#  [ 0.05533849  0.05539913  0.0554553  ... -0.62133218 -0.37256003
#   -0.16768072]
#  [ 0.05540972  0.05546537  0.05549373 ... -0.37249459 -0.16763836
#   -0.04338958]
#  ...
#  [ 0.23574443  0.23104407  0.22471624 ... -0.001897   -0.00183568
#   -0.00175852]
#  [ 0.2310549   0.22472652  0.21705258 ... -0.00177932 -0.00171824
#   -0.00164132]
# ...

# %%
# x_train, x_test, y_train, y_test = train_test_split(df.to_numpy().T,y.to_numpy().T,train_size=0.7,shuffle=True)
# df=df.to_numpy().T
#df=df.T
# y=y.to_numpy()

# x_train= df[0:8,:]
# x_valid=df[9:10,:]
# x_test= df[11:,:]

# y_train=y[0:8,:]
# y_valid=y[9:10,:]
# y_test= y[11:,:]

# x_train= df[0:70,:]
# x_valid=df[70:90,:]
# x_test= df[90:,:]

# y_train=y[0:70,:]
# y_valid=y[70:90,:]
# y_test= y[90:,:]


x_train= df[0:12000,:]
x_valid=df[12000:14000,:]
x_test= df[14000:15400,:]

# y_train=x_train[:,599].reshape(12000,1)
# y_valid=x_valid[:,599].reshape(2000,1)
# y_test= x_test[:,599].reshape(1400,1)

y_train=y[0:12000,:]
y_valid=y[12000:14000,:]
y_test= y[14000:15400,:]



# x_train=df.to_numpy().T[:48,:]
# x_valid=df.to_numpy().T[48:72,:]
# x_test=df.to_numpy().T[72:,:]
# y_train=y.to_numpy().T[:48,:]
# y_valid=y.to_numpy().T[48:72,:]
# y_test=y.to_numpy().T[72:,:]
#x_train, x_test = x_train / 255.0, x_test / 255.0

#x_valid, x_test, y_valid, y_test = train_test_split(x_test,y_test,train_size=0.5,shuffle=True)
# x_valid, x_test, y_valid, y_test = train_test_split(x_test,y_test,train_size=0.66667,shuffle=True)
print(x_train.shape)
print(y_train.shape)
print(x_valid.shape)
print(y_valid.shape)
print(x_test.shape)
print(y_test.shape)
print(x_train)
print(y_train)
# Out:
# (12000, 600)
# (12000, 1)
# (2000, 600)
# (2000, 1)
# (1400, 600)
# (1400, 1)
# [[ 0.05528027  0.0553279   0.05538907 ... -0.86875156 -0.62140372
#   -0.37260496]
#  [ 0.05533849  0.05539913  0.0554553  ... -0.62133218 -0.37256003
#   -0.16768072]
#  [ 0.05540972  0.05546537  0.05549373 ... -0.37249459 -0.16763836
#   -0.04338958]
#  ...
#  [-1.37411494 -1.37740903 -1.38054638 ... -0.12783515 -0.10432455
#   -0.07774984]
#  [-1.37740049 -1.38053821 -1.38350568 ... -0.10426568 -0.07770862
#   -0.04787271]
#  [-1.38052968 -1.38349752 -1.38633363 ... -0.0776504  -0.04783186
#   -0.01585325]]
# [[3.59568006]
#  [2.97450662]
#  [1.83539005]
#  ...
#  [0.36422136]
#  [0.43020698]
#  [0.42943458]]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (40, 10))
for i in range(11900,12000):
  plt.plot(x_train[i,:])

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (40, 20))
# plt.plot(yy[0,0:800],label="actual")
# plt.plot(yyy[0,0:800],label="predicted")
# for i in range(600,660):
plt.plot(x_train[599,:],'r')
plt.plot(y_train[0:599,:],'b')
plt.xlabel("Time (in sec)",fontsize=20)
plt.ylabel("Acceleration (in m/s^2)",fontsize=20)
plt.title("Plot showing comparison between actual training dataset and output acceleration response",fontsize=28)
plt.grid(True)
plt.legend(['x training dataset','y training acceleration response'],fontsize=20)

# %%
# fig = plt.figure(figsize = (40, 30))
# # plt.plot(yy[0,0:800],label="actual")
# # plt.plot(yyy[0,0:800],label="predicted")
# for i in range(11000,11020):
#   plt.plot(y_train[i,:])
# plt.xlabel("Data points")
# plt.ylabel("Values")
# plt.title("Plot showing comparison between actual test dataset values and predicted values")
# plt.grid(True)
# plt.legend()
plt.figure()
y_new=scaler.inverse_transform(y_train)
plt.plot(y_train)

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
# x_train = x_train.reshape((12000,600,1,1,1))
# x_valid= x_valid.reshape((2000,600,1,1,1))
# x_test = x_test.reshape((1400,600,1,1,1))

x_train = x_train.reshape((12000,600,1,1,1))
x_valid= x_valid.reshape((2000,600,1,1,1))
x_test = x_test.reshape((1400,600,1,1,1))

y_train = y_train.reshape(12000,1,1,1,1)
y_valid= y_valid.reshape(2000,1,1,1,1)
y_test = y_test.reshape(1400,1,1,1,1)
# x_train_new = x_train[0,:].reshape((48, 56))
# y_train_new= y_train[0,:]
print(x_train.shape)
print(y_train.shape)
# Out:
# (12000, 600, 1, 1, 1)
# (12000, 1, 1, 1, 1)

# %%
# !pip3 install keras-visualizer

import tensorflow.keras.layers as tfl
from tensorflow.keras import activations
from keras import models  
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation  
from keras.layers import Dense, Flatten, Conv3D, MaxPooling3D, Dropout, BatchNormalization
# from keras_visualizer import visualizer 
from keras import layers 
model = keras.models.Sequential()
# model.add(tfl.ZeroPadding1D(padding=1, input_shape = (2688, 1)))
# model.add(keras.layers.BatchNormalization(axis=2, ))

model.add(keras.layers.Conv3D(filters = 1, kernel_size = (5,1,1),strides= 1, input_shape = (600,1,1,1)))  #kernel_size = 5

#activation='relu', input_shape=x_train.shape[1:]
#model.add(keras.layers.MaxPooling1D(150))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.MaxPool2D())  #model.add(tfl.MaxPool2D(3,3))


# model.add(keras.layers.Conv1D(filters = 45, kernel_size = 7, strides= 2))
# model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.relu))


model.add(keras.layers.Conv3D(filters = 8, kernel_size = (5,1,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv3D(filters = 8, kernel_size = (5,1,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv3D(filters = 8, kernel_size = (5,1,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv3D(filters = 8, kernel_size = (5,1,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv3D(filters = 8, kernel_size = (5,1,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv3D(filters = 8, kernel_size = (5,1,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv3D(filters = 8, kernel_size = (5,1,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.Flatten())
# model.add(tfl.Dense(100))
# model.add(tfl.Dense(1))
model.add(keras.layers.Conv3D(filters = 1, kernel_size = (568,1,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)


# model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.relu))

# model.add(tfl.MaxPool1D())
# model.add(tfl.Flatten())
# model.add(tfl.Activation(activations.relu))

# model.add(tfl.Dense(100))
# model.add(tfl.Dense(8)) 

# model.add(keras.layers.Conv1D(128, (3), activation='relu'))
# model.add(keras.layers.MaxPooling1D((10,1)))
# model.add(keras.layers.Conv1D(256, (3), activation='relu'))
# model.add(keras.layers.Flatten())
# model.add(keras.layers.Dense(120, activation="relu"))
# model.add(keras.layers.Dense(84, activation="relu"))
# model.add(keras.layers.Dense(36, activation="relu"))
# model.add(keras.layers.Dense(8, activation="softmax"))
keras.utils.plot_model(model, show_shapes=True)
# model.summary()
# visualizer(model, format='png', view=True)

# %% [markdown]
# Response prediction CNN.pdf architecture

# %%
# !pip3 install keras-visualizer

import tensorflow.keras.layers as tfl
from tensorflow.keras import activations
from keras import models  
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation  
# from keras_visualizer import visualizer 
from keras import layers 
model = keras.models.Sequential()
# model.add(tfl.ZeroPadding1D(padding=1, input_shape = (2688, 1)))
# model.add(keras.layers.BatchNormalization(axis=2, ))

model.add(keras.layers.Conv2D(filters = 1, kernel_size = (5,1),strides= 1, input_shape = (600,1,1)))  #kernel_size = 5

#activation='relu', input_shape=x_train.shape[1:]
#model.add(keras.layers.MaxPooling1D(150))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.MaxPool2D())  #model.add(tfl.MaxPool2D(3,3))


# model.add(keras.layers.Conv1D(filters = 45, kernel_size = 7, strides= 2))
# model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.relu))


model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.Flatten())
# model.add(tfl.Dense(100))
# model.add(tfl.Dense(1))
model.add(keras.layers.Conv2D(filters = 1, kernel_size = (568,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)


# model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.relu))

# model.add(tfl.MaxPool1D())
# model.add(tfl.Flatten())
# model.add(tfl.Activation(activations.relu))

# model.add(tfl.Dense(100))
# model.add(tfl.Dense(8))

# model.add(keras.layers.Conv1D(128, (3), activation='relu'))
# model.add(keras.layers.MaxPooling1D((10,1)))
# model.add(keras.layers.Conv1D(256, (3), activation='relu'))
# model.add(keras.layers.Flatten())
# model.add(keras.layers.Dense(120, activation="relu"))
# model.add(keras.layers.Dense(84, activation="relu"))
# model.add(keras.layers.Dense(36, activation="relu"))
# model.add(keras.layers.Dense(8, activation="softmax"))
keras.utils.plot_model(model, show_shapes=True)
# model.summary()
# visualizer(model, format='png', view=True)

# %% [markdown]
# # my own architecture

# %%
# !pip3 install keras-visualizer

import tensorflow.keras.layers as tfl
from tensorflow.keras import activations
from keras import models  
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation  
# from keras_visualizer import visualizer 
from keras import layers 
model = keras.models.Sequential()
# model.add(tfl.ZeroPadding1D(padding=1, input_shape = (2688, 1)))
# model.add(keras.layers.BatchNormalization(axis=2, ))

model.add(keras.layers.Conv2D(filters = 1, kernel_size = (50,1),strides= 1, input_shape = (600,1,1)))  #kernel_size = 5

#activation='relu', input_shape=x_train.shape[1:]
#model.add(keras.layers.MaxPooling1D(150))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.MaxPool2D())  #model.add(tfl.MaxPool2D(3,3))
# model.add(tfl.MaxPool1D())

# model.add(keras.layers.Conv1D(filters = 45, kernel_size = 7, strides= 2))
# model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.relu))


model.add(keras.layers.Conv2D(filters = 8, kernel_size = (30,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.MaxPool2D())

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (30,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.MaxPool2D())

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (30,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.MaxPool2D())

model.add(keras.layers.Conv2D(filters = 8, kernel_size = (30,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.MaxPool2D())
model.add(keras.layers.Conv2D(filters = 8, kernel_size = (30,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.tanh))
# model.add(tfl.MaxPool2D())
# model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# # model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.tanh))

# model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# # model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.tanh))

# model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# # model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.tanh))

# model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# # model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.tanh))

# model.add(keras.layers.Conv2D(filters = 8, kernel_size = (5,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)
# # model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.tanh))
model.add(tfl.Flatten())
model.add(tfl.Dense(100))
model.add(tfl.Dense(1))
# model.add(keras.layers.Conv2D(filters = 1, kernel_size = (568,1),strides= 1))  #model.add(keras.layers.Conv2D(filters = 60, kernel_size = 2,strides= 1))  kernel_size = (1,2)


# model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.relu))

# model.add(tfl.MaxPool1D())
# model.add(tfl.Flatten())
# model.add(tfl.Activation(activations.relu))

# model.add(tfl.Dense(100))
# model.add(tfl.Dense(8))

# model.add(keras.layers.Conv1D(128, (3), activation='relu'))
# model.add(keras.layers.MaxPooling1D((10,1)))
# model.add(keras.layers.Conv1D(256, (3), activation='relu'))
# model.add(keras.layers.Flatten())
# model.add(keras.layers.Dense(120, activation="relu"))
# model.add(keras.layers.Dense(84, activation="relu"))
# model.add(keras.layers.Dense(36, activation="relu"))
# model.add(keras.layers.Dense(8, activation="softmax"))
keras.utils.plot_model(model, show_shapes=True)
# model.summary()
# visualizer(model, format='png', view=True)

# %% [markdown]
# #The CNN with a different architecture as per the latest partha da research paper

# %%
import tensorflow.keras.layers as tfl
from tensorflow.keras import activations
from keras import models  
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation  
# from keras_visualizer import visualizer 
from keras import layers 
model = keras.models.Sequential()
# model.add(tfl.ZeroPadding1D(padding=1, input_shape = (2688, 1)))
# model.add(keras.layers.BatchNormalization(axis=2, ))

model.add(keras.layers.Conv2D(filters = 100, kernel_size = (2,20),strides= 1,padding='valid',input_shape = (8, 2688,1)))  #model.add(keras.layers.Conv2D(filters = 100, kernel_size = 24,strides= 1,padding='valid',input_shape = (8, 2688,1)))

#activation='relu', input_shape=x_train.shape[1:]
#model.add(keras.layers.MaxPooling1D(150))
model.add(tfl.Activation(activations.relu))
# model.add(tfl.MaxPool1D(3,3))

# model.add(keras.layers.Conv1D(filters = 45, kernel_size = 7, strides= 2))
# model.add(tfl.Activation(activations.sigmoid))
# model.add(tfl.Activation(activations.relu))


model.add(keras.layers.Conv2D(filters = 100, kernel_size = (2,10),strides= 1,padding='valid'))
# model.add(tfl.Activation(activations.sigmoid))
model.add(tfl.Activation(activations.relu))
model.add(tfl.MaxPool2D())

model.add(keras.layers.Conv2D(filters = 100, kernel_size = (2,5),strides= 1,padding='valid'))
model.add(tfl.Activation(activations.relu))


# model.add(tfl.MaxPool1D())
model.add(tfl.Flatten())
# model.add(tfl.Activation(activations.relu))

model.add(tfl.Dense(100))
model.add(tfl.Dense(8))

# model.add(keras.layers.Conv1D(128, (3), activation='relu'))
# model.add(keras.layers.MaxPooling1D((10,1)))
# model.add(keras.layers.Conv1D(256, (3), activation='relu'))
# model.add(keras.layers.Flatten())
# model.add(keras.layers.Dense(120, activation="relu"))
# model.add(keras.layers.Dense(84, activation="relu"))
# model.add(keras.layers.Dense(36, activation="relu"))
# model.add(keras.layers.Dense(8, activation="softmax"))
keras.utils.plot_model(model, show_shapes=True)
# model.summary()
# visualizer(model, format='png', view=True)

# %%
x_train = x_train.reshape((12000,30,20,1,1))
x_valid= x_valid.reshape((4000,30,20,1,1))
x_test = x_test.reshape((1995,30,20,1,1))

y_train = y_train.reshape(12000,1,1,1,1)
y_valid= y_valid.reshape(4000,1,1,1,1)
y_test = y_test.reshape(1995,1,1,1,1)
# x_train_new = x_train[0,:].reshape((48, 56))
# y_train_new= y_train[0,:]
print(x_train.shape)
print(y_train.shape)
# Out:
# (12000, 30, 20, 1, 1)
# (12000, 1, 1, 1, 1)

# %%
# cp_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_path, 
#     verbose=1, 
#     save_weights_only=True,
#     save_freq=5*batch_size)
# callbacks = [
#     keras.callbacks.ModelCheckpoint("best_model.h5", save_best_only=True, monitor="val_loss"),keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001),
#     keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
# ]
# model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
#model.compile(optimizer="adam",loss=tf.keras.losses.CategoricalCrossentropy(),metrics=["accuracy"])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),loss=tf.keras.losses.MeanSquaredError(),metrics=tf.keras.metrics.RootMeanSquaredError()) #,metrics=['training loss']  learning_rate=1e-4
#history = model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_data=(x_valid, y_valid))
#history = model.fit(x_train, y_train, epochs=epochs, batch_size = 16,validation_data=(x_valid, y_valid))
history=model.fit(x_train, y_train, epochs=1000, batch_size=2000, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 29s 113ms/step - loss: 1.2217 - root_mean_squared_error: 1.1053 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1824
# Epoch 2/1000
# 6/6 [==============================] - 0s 80ms/step - loss: 1.0939 - root_mean_squared_error: 1.0459 - val_loss: 0.0420 - val_root_mean_squared_error: 0.2049
# Epoch 3/1000
# 6/6 [==============================] - 0s 79ms/step - loss: 1.0276 - root_mean_squared_error: 1.0137 - val_loss: 0.0609 - val_root_mean_squared_error: 0.2468
# Epoch 4/1000
# 6/6 [==============================] - 0s 81ms/step - loss: 0.9881 - root_mean_squared_error: 0.9940 - val_loss: 0.0582 - val_root_mean_squared_error: 0.2412
# Epoch 5/1000
# 6/6 [==============================] - 0s 81ms/step - loss: 0.9582 - root_mean_squared_error: 0.9789 - val_loss: 0.0639 - val_root_mean_squared_error: 0.2527
# Epoch 6/1000
# ...

# %%
# random maity
epochs = 100
batch_size = 16

# cp_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_path, 
#     verbose=1, 
#     save_weights_only=True,
#     save_freq=5*batch_size)
# callbacks = [
#     keras.callbacks.ModelCheckpoint("best_model.h5", save_best_only=True, monitor="val_loss"),keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001),
#     keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
# ]
# model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
#model.compile(optimizer="adam",loss=tf.keras.losses.CategoricalCrossentropy(),metrics=["accuracy"])
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),loss=tf.keras.losses.MeanSquaredError(),metrics=tf.keras.metrics.RootMeanSquaredError()) #,metrics=['training loss']  learning_rate=1e-4
#history = model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,validation_data=(x_valid, y_valid))
#history = model.fit(x_train, y_train, epochs=epochs, batch_size = 16,validation_data=(x_valid, y_valid))
history=model.fit(x_train, y_train, epochs=1000, batch_size=1024, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/1000
# 16/16 [==============================] - 3s 136ms/step - loss: 0.1298 - root_mean_squared_error: 0.3602 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074
# Epoch 2/1000
# 16/16 [==============================] - 2s 108ms/step - loss: 0.0609 - root_mean_squared_error: 0.2468 - val_loss: 0.0571 - val_root_mean_squared_error: 0.2389
# Epoch 3/1000
# 16/16 [==============================] - 2s 107ms/step - loss: 0.0457 - root_mean_squared_error: 0.2138 - val_loss: 0.0462 - val_root_mean_squared_error: 0.2150
# Epoch 4/1000
# 16/16 [==============================] - 2s 107ms/step - loss: 0.0401 - root_mean_squared_error: 0.2003 - val_loss: 0.0419 - val_root_mean_squared_error: 0.2048
# Epoch 5/1000
# 16/16 [==============================] - 2s 107ms/step - loss: 0.0374 - root_mean_squared_error: 0.1933 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1990
# Epoch 6/1000
# ...

# %%
#model = keras.models.load_model("best_model.h5")
# !mkdir -p saved_model
model.save('saved_model/my_model') 
new_model = tf.keras.models.load_model('saved_model/my_model')

# Check its architecture
new_model.summary()

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
model.summary()
# Out:
# INFO:tensorflow:Assets written to: saved_model/my_model/assets
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d (Conv3D)             (None, 596, 1, 1, 1)      6
#
#  activation (Activation)     (None, 596, 1, 1, 1)      0
#
#  conv3d_1 (Conv3D)           (None, 592, 1, 1, 8)      48
#
#  activation_1 (Activation)   (None, 592, 1, 1, 8)      0
#
#  conv3d_2 (Conv3D)           (None, 588, 1, 1, 8)      328
#
#  activation_2 (Activation)   (None, 588, 1, 1, 8)      0
#
#  conv3d_3 (Conv3D)           (None, 584, 1, 1, 8)      328
#
#  activation_3 (Activation)   (None, 584, 1, 1, 8)      0
#
#  conv3d_4 (Conv3D)           (None, 580, 1, 1, 8)      328
#
#  activation_4 (Activation)   (None, 580, 1, 1, 8)      0
#
#  conv3d_5 (Conv3D)           (None, 576, 1, 1, 8)      328
#
#  activation_5 (Activation)   (None, 576, 1, 1, 8)      0
#
# ...

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
#plt.gca().set_ylim(0, 1)
# plt.legend(('training loss', 'training accuracy', 'validation loss','validation accuracy'),
#            loc='upper center', shadow=True)
plt.xlabel("epocs")
plt.ylabel("value")
plt.title("Loss and RMSE for 2D CNN")
plt.show()

# %%
# Out:
# RootMeanSquaredError(name=root_mean_squared_error,dtype=float32)

# %%
metric = "rmse"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-fa024c3d0703> in <module>()
#       1 metric = "rmse"
#       2 plt.figure()
# ----> 3 plt.plot(history.history[metric])
#       4 plt.plot(history.history["val_" + metric])
#       5 plt.title("model " + metric)
#
# KeyError: 'rmse'

# %%
predictions=model.predict(x_test)
print(predictions)
#print(y_test)

#predictions[predictions]
# Out:
# [[[[[0.1228832 ]]]]
#
#
#
#  [[[[0.18061534]]]]
#
#
#
#  [[[[0.22767374]]]]
#
#
#
#  ...
#
#
#
#  [[[[0.01276807]]]]
#
#
#
#  [[[[0.01239981]]]]
#
#
#
#  [[[[0.01220594]]]]]

# %%
print(y_test)
# Out:
# [[[[[ 0.11397029]]]]
#
#
#
#  [[[[ 0.16081116]]]]
#
#
#
#  [[[[ 0.20920596]]]]
#
#
#
#  ...
#
#
#
#  [[[[ 0.01417808]]]]
#
#
#
#  [[[[-0.0061284 ]]]]
#
#
#
#  [[[[ 0.0016275 ]]]]]

# %%
import matplotlib.pyplot as plt


predictions= np.reshape(predictions,(1400,1))
y_test= np.reshape(y_test,(1400,1))
# from sklearn import preprocessing
# scaler = preprocessing.StandardScaler().fit(predictions)
# predictions= scaler.inverse_transform(predictions)
plt.figure(figsize = (40, 10),)
# y_new=scaler.inverse_transform(y_test)
# predictions_new= scaler.inverse_transform(predictions)
plt.plot(y_test)
# plt.plot(y_new)
plt.plot(predictions)
# plt.figure()
# plt.plot(x_test[:,599,0,0])
plt.ylabel('Acceleration (in m/s^2)',fontsize=20)
plt.xlabel('Time (sec)',fontsize=20)
plt.title('Actual and Predicted acceleration response on the test dataset',fontsize=28)
# plt.plot(scaler.inverse_transform(predictions))
# plt.legend("predicted")
plt.legend(['actual response','predicted response'],fontsize=20)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (40, 20),)
# y_new=scaler.inverse_transform(y_test)
# predictions_new= scaler.inverse_transform(predictions)
# a=[]
# l= [lambda x: x for x in range (12000)]
plt.plot(range(12000),x_train[:,599,0,0])
# plt.plot(y_new)
plt.plot(range(12000,14000),x_valid[:,599,0,0])
# plt.figure()
plt.plot(range(14000,15400),x_test[:,599,0,0])
plt.ylabel('Acceleration (in m/s^2)',fontsize=20)
plt.xlabel('Time (sec)',fontsize=20)
plt.title('Actual and Predicted acceleration response on the test dataset',fontsize=28)
# plt.plot(scaler.inverse_transform(predictions))
# plt.legend("predicted")
plt.legend(['actual','predicted'],fontsize=20)
plt.grid(True)
plt.show()

# %%
import sklearn
from sklearn.metrics import mean_squared_error
import math
from scipy.stats import pearsonr

actual = y_test.reshape(1400,1)

# actual = y_test.reshape(y_test.shape[0],y_test.shape[1])
predicted = predictions.reshape(1400,1)

mse = sklearn.metrics.mean_squared_error(actual, predicted)

rmse = math.sqrt(mse)

print(rmse)
print(np.shape(y_test))
x=0
for i in range(1400):
  x=math.sqrt(x*x+(predicted[i,0]-y_test[i,0])*(predicted[i,0]-y_test[i,0]))
print(x)
# print(np.corrcoef(predicted,actual))
print(np.mean(np.abs(1/1400*(predicted-actual) / actual)*100))
print(np.mean(np.abs(1/1400*(predicted-actual))))
actual = y_test.reshape(1400,)

# actual = y_test.reshape(y_test.shape[0],y_test.shape[1])
predicted = predictions.reshape(1400,)
print(pearsonr(predicted,actual))
# Out:
# 0.01682114573496418
# (1400, 1)
# 0.6293896419322973
# 0.12165356585466244
# 9.904937628494447e-06
# (0.9903933037360009, 0.0)

# %%
predictions=model.predict(x_valid)
print(predictions)
# Out:
# [[[[[0.45040482]]]]
#
#
#
#  [[[[0.43238914]]]]
#
#
#
#  [[[[0.42693734]]]]
#
#
#
#  ...
#
#
#
#  [[[[0.02791246]]]]
#
#
#
#  [[[[0.04519058]]]]
#
#
#
#  [[[[0.07160654]]]]]

# %%
import matplotlib.pyplot as plt


predictions= np.reshape(predictions,(2000,1))
yy= np.reshape(y_valid,(2000,1))
# from sklearn import preprocessing
# scaler = preprocessing.StandardScaler().fit(predictions)
# predictions= scaler.inverse_transform(predictions)
plt.figure(figsize = (40, 10))
# y_new=scaler.inverse_transform(y_test)
# predictions_new= scaler.inverse_transform(predictions)
plt.plot(yy)
# plt.plot(y_new)
plt.plot(predictions)
# plt.figure()
# plt.plot(x_test)
plt.ylabel('Acceleration (in m/s^2)',fontsize=20)
plt.xlabel('Time (sec)',fontsize=20)

plt.title('Actual and Predicted acceleration response on the validation dataset',fontsize=28)
# plt.plot(scaler.inverse_transform(predictions))
# plt.legend("predicted")
plt.legend(['actual','predicted'],fontsize=20)
plt.grid(True)
plt.show()

# %%
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-b296b54b08f3> in <module>()
#       2 df_loss= df_loss_acc[['loss','val_loss']]
#       3 df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# ----> 4 df_acc= df_loss_acc[['accuracy','val_accuracy']]
#       5 df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
#       6 df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
#
# ...
